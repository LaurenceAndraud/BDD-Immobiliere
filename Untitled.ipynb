# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('Valeurs_foncières.csv')
df
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_5040\3743481448.py:1: DtypeWarning: Columns (20,26,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Valeurs_foncières.csv')
#        Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0                  NaN                 NaN             NaN             NaN
# 1                  NaN                 NaN             NaN             NaN
# 2                  NaN                 NaN             NaN             NaN
# 3                  NaN                 NaN             NaN             NaN
# 4                  NaN                 NaN             NaN             NaN
# ...                ...                 ...             ...             ...
# 34164              NaN                 NaN             NaN             NaN
# 34165              NaN                 NaN             NaN             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34169 entries, 0 to 34168
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Reference document          0 non-null      float64
#  1   1 Articles CGI              0 non-null      float64
#  2   2 Articles CGI              0 non-null      float64
#  3   3 Articles CGI              0 non-null      float64
#  4   4 Articles CGI              0 non-null      float64
#  5   5 Articles CGI              0 non-null      float64
#  6   No disposition              34169 non-null  int64
#  7   Date mutation               34169 non-null  object
#  8   Nature mutation             34169 non-null  object
#  9   Valeur fonciere             34151 non-null  object
#  10  No voie                     34036 non-null  float64
#  11  B/T/Q                       2174 non-null   object
#  12  Code type de voie           34169 non-null  int64
# ...

# %%
mycolumns = ['Date mutation', 'Nature mutation', 'Nombre de lots', 'Code type local', 'Type local', 'Surface reelle bati', 'Nombre pieces principales', 'Valeur fonciere', 'No voie', 'B/T/Q']
df[mycolumns]
# Out:
#              Date mutation Nature mutation  Nombre de lots  Code type local  \
# 0      2020-02-03 00:00:00           Vente               1                2
# 1      2020-01-02 00:00:00           Vente               2                2
# 2      2020-01-08 00:00:00           Vente               2                2
# 3      2020-01-06 00:00:00           Vente               1                1
# 4      2020-01-07 00:00:00           Vente               2                2
# ...                    ...             ...             ...              ...
# 34164  2020-06-30 00:00:00           Vente               1                2
# 34165  2020-06-30 00:00:00           Vente               1                2
# 34166  2020-06-25 00:00:00           Vente               2                2
# 34167  2020-06-25 00:00:00           Vente               1                2
# 34168  2020-06-11 00:00:00           Vente               1                2
#
# ...

# %%
communes = pd.read_excel('donnees_communes.xlsx')
communes
# Out:
#                                REG  CODREG   COD  CODARR CODCAN  CODCOM  \
# 0            Auvergne-RhÃ´ne-Alpes    11.0  91.0     1.0     08   100.0
# 1            Auvergne-RhÃ´ne-Alpes    11.0  77.0     2.0   14.0   100.0
# 2            Auvergne-RhÃ´ne-Alpes    24.0  41.0     2.0     06   100.0
# 3            Auvergne-RhÃ´ne-Alpes    24.0  36.0     3.0     08   100.0
# 4            Auvergne-RhÃ´ne-Alpes    24.0  37.0     3.0     03   100.0
# ...                            ...     ...   ...     ...    ...     ...
# 34986  Provence-Alpes-CÃ´te d'Azur    93.0  13.0     1.0   28.0    99.0
# 34987  Provence-Alpes-CÃ´te d'Azur    93.0    06     2.0   26.0    99.0
# 34988  Provence-Alpes-CÃ´te d'Azur    93.0  84.0     1.0     08    99.0
# 34989  Provence-Alpes-CÃ´te d'Azur    93.0  83.0     1.0   11.0    99.0
# 34990  Provence-Alpes-CÃ´te d'Azur    94.0    2A     1.0   11.0    99.0
#
#                            COM    PMUN   PCAP    PTOT
# ...

# %%
mycolumns = ['REG', 'CODREG', 'COD', 'CODCOM', 'COM', 'PTOT']
communes[mycolumns]
# Out:
#                                REG  CODREG   COD  CODCOM  \
# 0            Auvergne-RhÃ´ne-Alpes    11.0  91.0   100.0
# 1            Auvergne-RhÃ´ne-Alpes    11.0  77.0   100.0
# 2            Auvergne-RhÃ´ne-Alpes    24.0  41.0   100.0
# 3            Auvergne-RhÃ´ne-Alpes    24.0  36.0   100.0
# 4            Auvergne-RhÃ´ne-Alpes    24.0  37.0   100.0
# ...                            ...     ...   ...     ...
# 34986  Provence-Alpes-CÃ´te d'Azur    93.0  13.0    99.0
# 34987  Provence-Alpes-CÃ´te d'Azur    93.0    06    99.0
# 34988  Provence-Alpes-CÃ´te d'Azur    93.0  84.0    99.0
# 34989  Provence-Alpes-CÃ´te d'Azur    93.0  83.0    99.0
# 34990  Provence-Alpes-CÃ´te d'Azur    94.0    2A    99.0
#
#                            COM    PTOT
# 0                     Bouville   662.0
# 1         Le ChÃ¢telet-en-Brie  4406.0
# 2                    Les Hayes   178.0
# 3       Lourouer-Saint-Laurent   267.0
# 4           Ã‰peignÃ©-les-Bois   410.0
# ...                        ...     ...
# ...

# %%
geo = pd.read_excel('fr-esr-referentiel-geographique.xlsx')
geo
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#       regrgp_nom                   reg_nom     reg_nom_old    aca_nom  \
# 0       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 1       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 2       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 3       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 4       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# ...          ...                       ...             ...        ...
# 38911   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes   Grenoble
# 38912   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes   Grenoble
# 38913   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes   Grenoble
# 38914   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes   Grenoble
# ...

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38916 entries, 0 to 38915
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   regrgp_nom         38916 non-null  object
#  1   reg_nom            38916 non-null  object
#  2   reg_nom_old        38916 non-null  object
#  3   aca_nom            38916 non-null  object
#  4   dep_nom            38916 non-null  object
#  5   com_code           38916 non-null  object
#  6   com_code1          38916 non-null  object
#  7   com_code2          38916 non-null  object
#  8   com_id             38916 non-null  object
#  9   com_nom_maj_court  38916 non-null  object
#  10  com_nom_maj        38916 non-null  object
#  11  com_nom            38916 non-null  object
#  12  uu_code            7625 non-null   object
#  13  uu_id              38916 non-null  object
#  14  uucr_id            38916 non-null  object
#  15  uucr_nom           38916 non-null  object
# ...

# %%
mycolumns = ['regrgp_nom', 'reg_nom', 'reg_nom_old', 'reg_code', 'reg_id', 'reg_code_old', 'reg_id_old']
geo[mycolumns]
# Out:
#       regrgp_nom                   reg_nom     reg_nom_old  reg_code reg_id  \
# 0       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0    R27
# 1       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0    R27
# 2       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0    R27
# 3       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0    R27
# 4       Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0    R27
# ...          ...                       ...             ...       ...    ...
# 38911   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0    R84
# 38912   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0    R84
# 38913   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0    R84
# 38914   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0    R84
# 38915   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0    R84
#
#        reg_code_old reg_id_old
# ...
