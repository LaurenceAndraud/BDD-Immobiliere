# %%
import pandas as pd
import sqlite3
import mysql.connector

# %%
df = pd.read_csv('Valeurs_foncières.csv')
df.head()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_5040\285720892.py:1: DtypeWarning: Columns (20,26,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Valeurs_foncières.csv')
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34169 entries, 0 to 34168
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Code service CH             0 non-null      float64
#  1   Reference document          0 non-null      float64
#  2   1 Articles CGI              0 non-null      float64
#  3   2 Articles CGI              0 non-null      float64
#  4   3 Articles CGI              0 non-null      float64
#  5   4 Articles CGI              0 non-null      float64
#  6   5 Articles CGI              0 non-null      float64
#  7   No disposition              34169 non-null  int64
#  8   Date mutation               34169 non-null  object
#  9   Nature mutation             34169 non-null  object
#  10  Valeur fonciere             34151 non-null  object
#  11  No voie                     34036 non-null  float64
#  12  B/T/Q                       2174 non-null   object
# ...

# %%
mycolumns = ['Date mutation', 'Valeur fonciere']
vente = df[mycolumns]
vente
# Out:
#              Date mutation Valeur fonciere
# 0      2020-02-03 00:00:00           56000
# 1      2020-01-02 00:00:00          165000
# 2      2020-01-08 00:00:00          720000
# 3      2020-01-06 00:00:00          429250
# 4      2020-01-07 00:00:00          220900
# ...                    ...             ...
# 34164  2020-06-30 00:00:00         1290000
# 34165  2020-06-30 00:00:00          726000
# 34166  2020-06-25 00:00:00          420000
# 34167  2020-06-25 00:00:00          725000
# 34168  2020-06-11 00:00:00          433000
#
# [34169 rows x 2 columns]

# %%
communes = pd.read_excel('donnees_communes.xlsx')
communes.head()
# Out:
#                      REG  CODREG   COD  CODARR CODCAN  CODCOM  \
# 0  Auvergne-RhÃ´ne-Alpes    11.0  91.0     1.0     08   100.0
# 1  Auvergne-RhÃ´ne-Alpes    11.0  77.0     2.0   14.0   100.0
# 2  Auvergne-RhÃ´ne-Alpes    24.0  41.0     2.0     06   100.0
# 3  Auvergne-RhÃ´ne-Alpes    24.0  36.0     3.0     08   100.0
# 4  Auvergne-RhÃ´ne-Alpes    24.0  37.0     3.0     03   100.0
#
#                       COM    PMUN  PCAP    PTOT
# 0                Bouville   646.0  16.0   662.0
# 1    Le ChÃ¢telet-en-Brie  4339.0  67.0  4406.0
# 2               Les Hayes   170.0   8.0   178.0
# 3  Lourouer-Saint-Laurent   261.0   6.0   267.0
# 4      Ã‰peignÃ©-les-Bois   406.0   4.0   410.0

# %%
communes = communes.rename(columns = {"PTOT":"pop_total"})
mycolumns = ['pop_total', 'CODREG', 'COD', 'CODCOM']
population = communes[mycolumns]
population
# Out:
#        pop_total  CODREG   COD  CODCOM
# 0          662.0    11.0  91.0   100.0
# 1         4406.0    11.0  77.0   100.0
# 2          178.0    24.0  41.0   100.0
# 3          267.0    24.0  36.0   100.0
# 4          410.0    24.0  37.0   100.0
# ...          ...     ...   ...     ...
# 34986      898.0    93.0  13.0    99.0
# 34987     1921.0    93.0    06    99.0
# 34988     4706.0    93.0  84.0    99.0
# 34989     8170.0    93.0  83.0    99.0
# 34990      276.0    94.0    2A    99.0
#
# [34991 rows x 4 columns]

# %%
geo = pd.read_excel('fr-esr-referentiel-geographique.xlsx')
geo.head()
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#   regrgp_nom                   reg_nom     reg_nom_old    aca_nom  \
# 0   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 1   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 2   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 3   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
# 4   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©  BesanÃ§on
#
#         dep_nom com_code com_code1 com_code2  com_id  \
# 0  Haute-SaÃ´ne  70088.0   70088.0   70088.0  C70088
# 1  Haute-SaÃ´ne  70095.0   70095.0   70095.0  C70095
# 2  Haute-SaÃ´ne  70101.0   70101.0   70101.0  C70101
# 3  Haute-SaÃ´ne  70111.0   70111.0   70111.0  C70111
# 4  Haute-SaÃ´ne  70116.0   70116.0   70116.0  C70116
#
#             com_nom_maj_court  ...  fd_id fr_id fe_id uu_id_99 au_code  au_id  \
# ...

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38916 entries, 0 to 38915
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   regrgp_nom         38916 non-null  object
#  1   reg_nom            38916 non-null  object
#  2   reg_nom_old        38916 non-null  object
#  3   aca_nom            38916 non-null  object
#  4   dep_nom            38916 non-null  object
#  5   com_code           38916 non-null  object
#  6   com_code1          38916 non-null  object
#  7   com_code2          38916 non-null  object
#  8   com_id             38916 non-null  object
#  9   com_nom_maj_court  38916 non-null  object
#  10  com_nom_maj        38916 non-null  object
#  11  com_nom            38916 non-null  object
#  12  uu_code            7625 non-null   object
#  13  uu_id              38916 non-null  object
#  14  uucr_id            38916 non-null  object
#  15  uucr_nom           38916 non-null  object
# ...

# %%
mycolumns = ['reg_id', 'regrgp_nom', 'reg_nom', 'reg_nom_old', 'reg_code', 'reg_code_old', 'reg_id_old']
region = geo[mycolumns]
region
# Out:
#       reg_id regrgp_nom                   reg_nom     reg_nom_old  reg_code  \
# 0        R27   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0
# 1        R27   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0
# 2        R27   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0
# 3        R27   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0
# 4        R27   Province  Bourgogne-Franche-ComtÃ©  Franche-ComtÃ©      27.0
# ...      ...        ...                       ...             ...       ...
# 38911    R84   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0
# 38912    R84   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0
# 38913    R84   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0
# 38914    R84   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0
# 38915    R84   Province     Auvergne-RhÃ´ne-Alpes    RhÃ´ne-Alpes      84.0
#
#        reg_code_old reg_id_old
# ...

# %%
geo = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "",
    database = "immobilier"
)

cursor = geo.cursor()

sql = "INSERT INTO region() VALUES(%s,%s,%s)"
for i,row in geo.iterrows():
    cursor.execute(sql, tuple(row))
    db.commit()

geo.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 11>()
#       8 cursor = geo.cursor()
#      10 sql = "INSERT INTO bien(ID_bien, No_voie, type_voie, voie, total_piece, surface_carrez, surface_local, type_local, ID_codedep_codecommune) VALUES(%s,%s,%s)"
# ---> 11 for i,row in region.iterrows():
#      12     cursor.execute(sql, tuple(row))
#      13     db.commit()
#
# NameError: name 'region' is not defined
